# %%
#sample
for i in range(9):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 8

# %%
#runtime input
a=int(input("A value"))
b=int(input("B value"))
print("sum",a+b)
# Out:
# A value 10
# B value 20
# sum 30
